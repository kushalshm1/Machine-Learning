# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

trainData = pd.DataFrame(pd.read_csv("train.csv"))
del trainData['Alley'],trainData['Street'],trainData['LotShape'],trainData['LandContour'],trainData['LotConfig'],
del trainData['LandSlope'],trainData['Neighborhood'],trainData['Condition1'],trainData['Condition2'],trainData['PoolArea'],trainData['PoolQC'],
del trainData['Fence'],trainData['MiscFeature'],trainData['MiscVal'],trainData['SaleType'],trainData['SaleCondition'],trainData['BldgType'],trainData['HouseStyle']
# print(trainData.iloc[1])
# add = 0

# def derivativeSlope(w,c):
#     global trainData,add,realPrices
#     for x in range(len(trainData)):
#         add = add + np.add((np.dot(w,trainData.iloc[x])),c) - realPrices[x]
# def derivativeIntercept(w,c):

print(trainData)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Utilities  OverallQual  \
# 0        1          60       RL           65     8450    AllPub            7
# 1        2          20       RL           80     9600    AllPub            6
# 2        3          60       RL           68    11250    AllPub            7
# 3        4          70       RL           60     9550    AllPub            7
# 4        5          60       RL           84    14260    AllPub            8
# 5        6          50       RL           85    14115    AllPub            5
# 6        7          20       RL           75    10084    AllPub            8
# 7        8          60       RL          NaN    10382    AllPub            7
# 8        9          50       RM           51     6120    AllPub            7
# 9       10         190       RL           50     7420    AllPub            5
# 10      11          20       RL           70    11200    AllPub            5
# ...

# %%
trainData
# Out:
#       ID      crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0      1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1      2   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2      4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 3      5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 4      7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 5     11   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 6     12   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# 7     13   0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311
# 8     14   0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 9     15   0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 10    16   0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# ...
